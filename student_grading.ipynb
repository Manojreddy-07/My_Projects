# %%
#sample project on assigning grades to students and accessing them to fetch average and remove the particular student from the list
import statistics
def grade_points():#a function to covert the grades to integer values of score
    if (std_grade=='S'):
        return 100
    elif(std_grade=='A'):
        return 90
    elif(std_grade=='B'):
        return 80
    elif(std_grade=='C'):
        return 70
    elif(std_grade=='D'):
        return 60
    else:
        print("student failed")
#here we are accessing the details of user to verify for the log in 
username="Manoj"
password=4603
ip_username=input("enter username:")
ip_password=int(input("enter 4 digit password:"))
if(ip_username==username and ip_password==password):
    print("you have successfully logged in..........:")
    #here we start forming students list and their respective grades  using data types dictionary and lists 
    std_grading_system={}
    std_grades=[]
    students_length=int(input("enter number of students(keys):"))
    courses_length=int(input("enter number of courses(values):"))

    while len(std_grading_system)<students_length:
            std_name=input("enter next student name:")
            for i in range(courses_length):
                std_grade=input("enter his grade:")
                score=grade_points()
                std_grades.append(score)
            std_grading_system[std_name]=std_grades
            std_grades = []
            
    print(std_grading_system)
    #A function to calculate the average of  student u want know
    def average_grades(x):
        student=input("enter the student name,to know his/her average of grades:")
        for key in std_grading_system:
            if(key==student):
                print("the average of grades equals to:",float(statistics.mean(x[student])))
                break
            else:
                continue
        print("there is no student named:",student,"in the list")
    
    average_grades(std_grading_system)

    #Afunction to remove the student from the given list
    def remove_student(d):
        std_name=input("enter student name u want to remove:")
        for key in std_grading_system:
            if(key==std_name):
                del d[std_name]
                break
            else:
                continue
        print("there is no student named:",std_name,"in the list")
        
    remove_student(std_grading_system)
else:
    print("Invalid username or password.....")
